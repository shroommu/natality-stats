# %% [markdown]
# # 2021 CDC Natality Data
#
# Every year, millions of babies are born in the United States. Anonymized data surrounding each birth is collected by the CDC and made available to the public. Here we will explore that data.

# %% [markdown]
# ### Common Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Load Data and Clean

# %%
year = 2022

# %%
df = pd.read_parquet(f"../../data/{year}/processed/natality_{year}_numeric.parquet")

# %%
df.head()
# Out:
#    birth_year  birth_month  time_of_birth  birth_day_of_week  birth_place  \
# 0        2022            1           1218                  7            2
# 1        2022            1           1525                  7            3
# 2        2022            1            539                  2            3
# 3        2022            1            122                  6            3
# 4        2022            1           1801                  1            1
#
#    facility_reporting_flag  facility_recode  mothers_age_imputed  \
# 0                        1                2                  NaN
# 1                        1                2                  NaN
# 2                        1                2                  NaN
# 3                        1                2                  NaN
# 4                        1                1                  NaN
#
#    reported_mothers_age_used  mothers_single_year_age  ...  \
# 0                        NaN                       37  ...
# 1                        NaN                       27  ...
# 2                        NaN                       25  ...
# 3                        NaN                       42  ...
# 4                        NaN                       27  ...
#
#    cleft_lip_reporting_flag  cleft_palate_reporting_flag  \
# 0                         1                            1
# 1                         1                            1
# 2                         1                            1
# 3                         1                            1
# 4                         1                            1
#
#    down_syndrome_reporting_flag  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
#    suspected_chromosomal_disorder_reporting_flag  hypospadias_reporting_flag  \
# 0                                              1                           1
# 1                                              1                           1
# 2                                              1                           1
# 3                                              1                           1
# 4                                              1                           1
#
#    no_congenital_abnormalities_reported  infant_transferred  \
# 0                                     1                 0.0
# 1                                     1                 0.0
# 2                                     1                 0.0
# 3                                     1                 0.0
# 4                                     1                 0.0
#
#    infant_living_at_time_of_report  infant_breastfed_at_discharge  \
# 0                              1.0                            1.0
# 1                              1.0                            1.0
# 2                              1.0                            1.0
# 3                              1.0                            1.0
# 4                              1.0                            1.0
#
#    infant_breastfed_at_discharge_reporting_flag
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
# [5 rows x 226 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3676029 entries, 0 to 3676028
# Columns: 226 entries, birth_year to infant_breastfed_at_discharge_reporting_flag
# dtypes: float32(62), float64(3), int16(9), int8(152)
# memory usage: 1.5 GB

# %% [markdown]
# We have too many features to easily view null counts. We know some columns from the user guide will not be useful, so we'll start by dropping those.

# %%
flag_column_names = df.filter(regex="(.*imputed.*|.*flag.*)$", axis=1).columns

flag_column_names_list = flag_column_names.to_list()

df = df.drop(flag_column_names_list, axis="columns")

# %% [markdown]
# Our parquet file also includes a column that is just filled by the birth year. We'll drop that as well.

# %%
df = df.drop(["birth_year"], axis="columns")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3676029 entries, 0 to 3676028
# Columns: 144 entries, birth_month to infant_breastfed_at_discharge
# dtypes: float32(54), float64(3), int16(8), int8(79)
# memory usage: 1.1 GB

# %% [markdown]
# That cut our features down to a more manageable 144. That's still too many to easily view our null values using `info()`, so we'll use another method to examine our null values.

# %%
null_counts_df = df.isnull().sum().reset_index()
null_counts_df.columns = ["column_name", "null_count"]

null_counts_df
# Out:
#                               column_name  null_count
# 0                             birth_month           0
# 1                           time_of_birth           0
# 2                       birth_day_of_week           0
# 3                             birth_place           0
# 4                         facility_recode           0
# ..                                    ...         ...
# 139                           hypospadias        7501
# 140  no_congenital_abnormalities_reported           0
# 141                    infant_transferred        8644
# 142       infant_living_at_time_of_report        5229
# 143         infant_breastfed_at_discharge      444885
#
# [144 rows x 2 columns]

# %%
columns_with_nulls = null_counts_df[null_counts_df["null_count"] > 0][
    "column_name"
].tolist()

print("Number of columns with nulls:", len(columns_with_nulls))
# Out:
# Number of columns with nulls: 56

# %% [markdown]
# We have 56 columns with null values. Some have significantly more nulls than others, so different methods will need to be applied to remove or impute those values.

# %%
null_counts_df.sort_values("null_count", ascending=False)
# Out:
#                               column_name  null_count
# 5               reported_mothers_age_used     3675939
# 69      assistive_reproductive_technology     3589222
# 68              fertility_enhancing_drugs     3589222
# 90   trial_of_labor_attempted_if_cesarean     2505766
# 17                 paternity_acknowledged     2378123
# ..                                    ...         ...
# 115             obstetric_estimate_edited           0
# 116          obstetric_estimate_recode_10           0
# 117           obstetric_estimate_recode_3           0
# 118                 birth_weight_in_grams           0
# 140  no_congenital_abnormalities_reported           0
#
# [144 rows x 2 columns]

# %%
sns.barplot(
    x="null_count",
    y="column_name",
    data=null_counts_df.sort_values("null_count", ascending=False).head(20),
)
plt.title("Top 20 Columns with Most Null Values")
plt.xlabel("Number of Null Values")
plt.ylabel("Column Name")
plt.show()

# %% [markdown]
# We'll opt to drop the top five columns as they are more null values than recorded values.

# %%
df = df.drop(
    [
        "reported_mothers_age_used",
        "assistive_reproductive_technology",
        "fertility_enhancing_drugs",
        "trial_of_labor_attempted_if_cesarean",
        "paternity_acknowledged",
    ],
    axis="columns",
)

# %% [markdown]
# The remainder of our columns with null values can be addressed by imputation. We'll deal with each column on an as-needed basis in targeted analysis.

# %% [markdown]
# Finally, we'll save out our cleaned dataset as a new parquet file.

# %%
df.to_parquet(
    f"../../data/{year}/processed/natality_{year}_cleaned.parquet", index=False
)
